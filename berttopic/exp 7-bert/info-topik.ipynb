# %%
import pandas as pd
topik = pd.read_csv(r'C:\Users\Liza\Documents\Kerja Praktik FIXX\Emilia-dataset-evaluation\berttopic\exp 7-bert\after_reassign_indobert_clean.csv', sep=';', on_bad_lines='skip') 
topik.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7488 entries, 0 to 7487
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   question               7488 non-null   object
#  1   answer                 7488 non-null   object
#  2   from                   7488 non-null   object
#  3   filename               7488 non-null   object
#  4   document_preprocessed  7488 non-null   object
#  5   Topic                  7488 non-null   int64
#  6   Probability            7488 non-null   float64
#  7   Top_n_words            7488 non-null   object
#  8   Name                   7488 non-null   object
#  9   Document               7488 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 585.1+ KB

# %%
# 1. Menampilkan distribusi jumlah data untuk setiap ID Topik
print("=== JUMLAH DATA PER TOPIK ===")
distribusi_topik = topik['Topic'].value_counts().reset_index()
distribusi_topik.columns = ['ID Topik', 'Jumlah Data']
print(distribusi_topik.to_string(index=False))

print("-" * 50)

# 2. Menampilkan total berapa banyak kelompok topik yang terbentuk
total_topik_unik = topik['Topic'].nunique()
print(f"Total seluruh topik unik yang terbentuk: {total_topik_unik} topik")
# Out:
# === JUMLAH DATA PER TOPIK ===
#  ID Topik  Jumlah Data
#         0         5014
#         2          595
#         1          489
#         3          196
#         5          171
#        10          162
#         6          161
#        12          160
#        11          160
#         4           90
#         7           89
#         8           71
#        13           67
#         9           49
#        -1           14
# --------------------------------------------------
# Total seluruh topik unik yang terbentuk: 15 topik
